# %% [markdown]
# # APS 5 - Questões com auxílio do Pandas

# %% [markdown]
# ** Nome: ** <font color=blue> João Gabriel Rodrigues Edivirges </font>

# %% [markdown]
# APS **INDIVIDUAL**
#
# Data de Entrega: 26/Set até às 23h59 via GitHub.
#
# Vamos trabalhar com dados do USGS (United States Geological Survey) para tentar determinar se os abalos detectados no hemisfério Norte têm grande probabilidade de serem testes nucleares.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

# %%
#Abrir o arquivo
df = pd.read_csv('earthquake(1).csv')
#listar colunas
print(list(df))
# Out:
# ['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error', 'Depth Seismic Stations', 'Magnitude', 'Magnitude Type', 'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID', 'Source', 'Location Source', 'Magnitude Source', 'Status']

# %% [markdown]
# ## Liste as primeiras linhas do DataFrame

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type    ...      \
# 0                     NaN        6.0             MW    ...
# 1                     NaN        5.8             MW    ...
# 2                     NaN        6.2             MW    ...
# 3                     NaN        5.8             MW    ...
# 4                     NaN        5.8             MW    ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Q1 - Manipulando o DataFrame
#
# Crie uma coluna chamada `Hemisfério` baseada na Latitude
#
# A regra de formação é a seguinte:
#
# Valor | Critério
# ---|---
# Norte | Latitude positiva
# Sul | Latitude negativa

# %%
# df=df[df.Latitude>0]
df['Hemisferio']=0
df.loc[(df.Latitude>0),'Hemisferio']='Norte'
df.loc[(df.Latitude<0),'Hemisferio']='Sul'
df.Hemisferio.head()
# Out:
# 0    Norte
# 1    Norte
# 2      Sul
# 3      Sul
# 4    Norte
# Name: Hemisferio, dtype: object

# %%
df.Magnitude.describe()
# Out:
# count    23412.000000
# mean         5.882531
# std          0.423066
# min          5.500000
# 25%          5.600000
# 50%          5.700000
# 75%          6.000000
# max          9.100000
# Name: Magnitude, dtype: float64

# %% [markdown]
# ## Q2 - Fit e Histograma
#
# Faça o Histograma da Magnitude. Interprete.

# %% [markdown]
# Como pode-se ver no histograma gerado, mais de 80% dos terremotos ocorreram na faixa de 5.5 e 6.5 graus na escala Richter. Os demais incidentes, distribuem-se em 10% para terremotos entre 6.5 e 7.5 na Richter e os mais graves, 8 até 8.5, são os com menos ocorrência.

# %%
faixa=np.arange(5.5,9.1,1)
plot=df.Magnitude.plot.hist(bins=faixa,title='Magnitude',figsize=(6,6),normed=1,grid=1,color='r')

# %% [markdown]
# Faça o fit de uma distribuição exponencial sobre os dados da Magnitude, achando os valores de **loc** e **scale**. Interprete loc e scale no caso da exponencial.
# Documentação: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html

# %%
#para fazer uma dist exponencial, leva-se em conta que o loc=0 e o lamb=1/desvpad
desvpad=0.423066
lamb=1/desvpad
#relação loc e scale
loc=0
scale=1/lamb
#dados
X=expon.rvs(loc,scale,len(df.Magnitude))
#plot
fig, ax= plt.subplots(1,2,figsize=(15,3))
#histograma vs fdp
ax[0].hist(X,normed=True)
x=np.arange(X.min(), X.max(), 0.1)
ax[0].plot(x, expon.pdf(x, loc, scale))
ax[0].set_title('Hist vs fdp')
ax[0].legend(['Modelo','Simulado'])
#cdf
ax[1].plot(x,expon.cdf(x, loc, scale))
ax[1].set_title('Cumulative Distribution')
ax[1].legend(['cdf'])

# %% [markdown]
# Refaça o Histograma plotando a fdp (função densidade de probabilidade) da exponencial com os parâmetros achados no fit em cima. Cuidado com o domínio utilizado. Interprete.

# %% [markdown]
# ## Q3 - Tabela cruzada
#
# Faça uma tabela de cruzamento das variáveis `Hemisfério` e `Type`
#
# Sua tabela deve ser <font color=red> normalizada</font>

# %%
tab=pd.crosstab(df.Hemisferio, df.Type,margins=True,rownames=['Hemisferio'], colnames=['Acidentes'], normalize=True)*100
tab
# Out:
# Acidentes   Earthquake  Explosion  Nuclear Explosion  Rock Burst         All
# Hemisferio
# 0             0.004271   0.000000           0.000000    0.000000    0.004271
# Norte        44.712113   0.008543           0.627883    0.000000   45.348539
# Sul          54.514779   0.008543           0.119597    0.004271   54.647189
# All          99.231164   0.017085           0.747480    0.004271  100.000000

# %% [markdown]
# ### Q3.1 - Qual a probabilidade de ocorrer um terremoto no hemisfério norte?

# %% [markdown]
# Adicione na célula abaixo o cálculo:

# %% [markdown]
# prob=45.348539%

# %% [markdown]
# Explique o seu raciocínio

# %% [markdown]
# Uma vez que a tab está normalizada, verifica-se que a prob total na coluna all é 45,3%. Se não estivesse, a probabilidade seria a soma de todos os eventos dividido pelo total

# %% [markdown]
# ### Q3.2 - Dado que aconteceu no Norte, qual a probabilidade de ele ter sido `Nuclear Explosion`?

# %% [markdown]
# Calcule a resposta abaixo, ou explique como a encontrou

# %% [markdown]
# Se for cálculo preencha a célula a seguir:

# %% [markdown]
# Se conseguir obter a resposta sem calcular, insira a resposta abaixo:
#
# * A probabilidade de ter sido `Nuclear Explosion` é ...

# %%
a=0.627883/45.348539
print("A probabilidade de ter sido Nuclear Explosion é :{0}%".format(a))
# Out:
# A probabilidade de ter sido Nuclear Explosion é :0.013845716176214629%

# %% [markdown]
# ## Q4 - Análise bivariada
#
# Faça o *plot* de dispersão (*scatter plot*) entre as variáveis `Magnitude Error`  e `Depth`

# %%
plt.scatter(df['Magnitude Error'],df.Depth,c='y',alpha=0.2)
plt.grid(True)

# %% [markdown]
# Calcule a correlação entre as variáveis `Magnitude Error`  e `Depth`

# %%
#correcoef ignora missing data (type nan)
# cor=np.corrcoef(df['Magnitude Error'],df.Depth)
# print (cor)
#do np da ruim
cor=df.Depth.corr(df['Magnitude Error'])
cor
# Out:
# -0.076918438923387192

# %% [markdown]
# Explique o que significa o valor da correlação calculada acima?

# %%
#não sei explicar

# %% [markdown]
# ## Q5 - Describe e boxplot
#
# Faça o `describe` e o *boxplot* da `Latitude` e da `Longitude`. Explique os valores

# %%
df.Longitude.describe()
# Out:
# count    23412.000000
# mean        39.639961
# std        125.511959
# min       -179.997000
# 25%        -76.349750
# 50%        103.982000
# 75%        145.026250
# max        179.998000
# Name: Longitude, dtype: float64

# %%
df.Latitude.describe()
# Out:
# count    23412.000000
# mean         1.679033
# std         30.113183
# min        -77.080000
# 25%        -18.653000
# 50%         -3.568500
# 75%         26.190750
# max         86.005000
# Name: Latitude, dtype: float64

# %%
plot=df.boxplot(column=['Latitude','Longitude'])
plt.ylabel("Graus")

# %% [markdown]
# O boxplot indica que no caso da latitude, os valores de graus estão dispersos numa distribuição em relação aos acidentes, aonde o os valores do primeiro estão abaixo da mediana, que se localiza próximo ao zero. No caso da latitude, a mediana está em 0 Graus, o Q1 está entre 0 e aproximadamente -20, o Q3 está entre 0 e aproximadamente 30.Já na longitude, a mediana está em 100, o q1 está entre -50 e perto de 100. Já o Q3 está entre 150 e 100.Isso mostra que as possíveis localizações de um acidente estão nessa faixa de 25% e 75% com as respectivas coordenadas.

# %% [markdown]
# ## Q6 - Tirando conclusões com base nos dados
#
# Em um certo lugar já ocorreram abalos com *Magnitude Type* `MB` e *Type* `Nuclear Explosion`.
#
# Responda:
#     * É mais provável que tenha sido no norte ou no sul?
#
# Assuma que os Magnitude Type e Type são independentes

# %%
#selecionar os MT do tipo MB
mb=df[df['Magnitude Type']=='MB']
mb
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 2576   01/02/1973  00:53:20   -9.8540   117.4270  Earthquake   66.00
# 2577   01/03/1973  02:58:17  -27.7160   -63.2610  Earthquake  563.00
# 2578   01/03/1973  14:31:05   39.1140    71.8890  Earthquake   33.00
# 2579   01/05/1973  13:54:29  -38.9970   175.2320  Earthquake  150.00
# 2580   01/06/1973  15:52:42  -14.6650   166.3840  Earthquake   36.00
# 2584   01/12/1973  03:16:03  -54.4080     5.3570  Earthquake   33.00
# 2585   01/15/1973  09:02:58   27.0810   140.1030  Earthquake  477.00
# 2586   01/16/1973  09:47:02   -3.5280   135.4740  Earthquake    7.00
# 2587   01/17/1973  09:44:37  -15.1270  -175.0080  Earthquake  251.00
# 2590   01/21/1973  20:20:49  -15.8570  -174.0550  Earthquake  129.00
# 2592   01/23/1973  04:49:46  -12.0910   166.4990  Earthquake   97.00
# 2593   01/26/1973  21:33:55    0.3760   122.2240  Earthquake  115.00
# 23371  12/08/2016  21:48:34  -10.8691   161.2302  Earthquake   27.20
# 23374  12/09/2016  19:13:23  -11.0704   161.4548  Earthquake   39.04
# 23375  12/09/2016  19:43:24  -10.9719   161.3099  Earthquake   19.68
# 23387  12/17/2016  11:22:40   -4.4244   153.5419  Earthquake   83.36
# 23393  12/18/2016  11:35:48  -10.1904   161.2187  Earthquake   57.52
# 23404  12/25/2016  14:32:13  -43.4810   -74.4771  Earthquake   14.93
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 2576           NaN                     NaN        5.5             MB
# 2577           NaN                     NaN        5.6             MB
# 2578           NaN                     NaN        5.5             MB
# 2579           NaN                     NaN        6.2             MB
# 2580           NaN                     NaN        6.1             MB
# 2584           NaN                     NaN        5.7             MB
# 2585           NaN                     NaN        5.8             MB
# 2586           NaN                     NaN        5.5             MB
# 2587           NaN                     NaN        5.7             MB
# 2590           NaN                     NaN        5.5             MB
# 2592           NaN                     NaN        5.8             MB
# 2593           NaN                     NaN        5.6             MB
# 2594           NaN                     NaN        6.0             MB
# 2595           NaN                     NaN        5.7             MB
# 2597           NaN                     NaN        6.0             MB
# 2598           NaN                     NaN        6.1             MB
# 2599           NaN                     NaN        5.6             MB
# 2600           NaN                     NaN        5.7             MB
# 2602           NaN                     NaN        5.7             MB
# 2603           NaN                     NaN        5.8             MB
# 2606           NaN                     NaN        5.5             MB
# 2607           NaN                     NaN        5.5             MB
# 2608           NaN                     NaN        5.5             MB
# 2609           NaN                     NaN        5.9             MB
# 2610           NaN                     NaN        5.9             MB
# 2613           NaN                     NaN        5.8             MB
# 2614           NaN                     NaN        5.6             MB
# 2615           NaN                     NaN        5.5             MB
# 2616           NaN                     NaN        5.5             MB
# 2617           NaN                     NaN        5.5             MB
# ...            ...                     ...        ...            ...
# 23010          1.7                     NaN        5.5             MB
# 23067          3.5                     NaN        5.5             MB
# 23113          1.9                     NaN        5.5             MB
# 23182          1.8                     NaN        5.5             MB
# 23187          1.8                     NaN        5.5             MB
# 23194          5.1                     NaN        5.6             MB
# 23205          1.7                     NaN        5.5             MB
# 23214          1.8                     NaN        5.7             MB
# 23223          5.1                     NaN        5.8             MB
# 23234          5.1                     NaN        5.5             MB
# 23235          0.8                     NaN        5.5             MB
# 23236          1.7                     NaN        5.7             MB
# 23239          2.8                     NaN        5.5             MB
# 23241          1.8                     NaN        5.5             MB
# 23246          1.8                     NaN        5.5             MB
# 23261          4.1                     NaN        5.5             MB
# 23327          4.5                     NaN        5.7             MB
# 23328          1.9                     NaN        5.5             MB
# 23330          1.1                     NaN        5.8             MB
# 23331          2.1                     NaN        5.7             MB
# 23353          1.8                     NaN        5.5             MB
# 23354          6.1                     NaN        5.6             MB
# 23370          2.0                     NaN        5.7             MB
# 23371          1.2                     NaN        5.5             MB
# 23374          8.4                     NaN        5.5             MB
# 23375          3.5                     NaN        5.5             MB
# 23387          5.1                     NaN        5.6             MB
# 23393          5.2                     NaN        5.5             MB
# 23404          3.3                     NaN        5.6             MB
# 23411          2.2                     NaN        5.5             MB
#
#          ...     Magnitude Seismic Stations  Azimuthal Gap  \
# 2576     ...                            NaN            NaN
# 2577     ...                            NaN            NaN
# 2578     ...                            NaN            NaN
# 2579     ...                            NaN            NaN
# 2580     ...                            NaN            NaN
# 2584     ...                            NaN            NaN
# 2585     ...                            NaN            NaN
# 2586     ...                            NaN            NaN
# 2587     ...                            NaN            NaN
# 2590     ...                            NaN            NaN
# 2592     ...                            NaN            NaN
# 2593     ...                            NaN            NaN
# 2594     ...                            NaN            NaN
# 2595     ...                            NaN            NaN
# 2597     ...                            NaN            NaN
# 2598     ...                            NaN            NaN
# 2599     ...                            NaN            NaN
# 2600     ...                            NaN            NaN
# 2602     ...                            NaN            NaN
# 2603     ...                            NaN            NaN
# 2606     ...                            NaN            NaN
# 2607     ...                            NaN            NaN
# 2608     ...                            NaN            NaN
# 2609     ...                            NaN            NaN
# 2610     ...                            NaN            NaN
# 2613     ...                            NaN            NaN
# 2614     ...                            NaN            NaN
# 2615     ...                            NaN            NaN
# 2616     ...                            NaN            NaN
# 2617     ...                            NaN            NaN
# ...      ...                            ...            ...
# 23010    ...                          160.0           48.0
# 23067    ...                          205.0           44.0
# 23113    ...                           76.0          152.0
# 23182    ...                          210.0           83.0
# 23187    ...                           40.0           53.0
# 23194    ...                          191.0           33.0
# 23205    ...                          258.0           31.0
# 23214    ...                           21.0          112.0
# 23223    ...                          109.0           13.0
# 23234    ...                           18.0          201.0
# 23235    ...                           54.0           99.0
# 23236    ...                           93.0           37.0
# 23239    ...                          149.0           58.0
# 23241    ...                           75.0           72.0
# 23246    ...                          231.0           49.0
# 23261    ...                          145.0           39.0
# 23327    ...                           49.0           79.0
# 23328    ...                           12.0           81.0
# 23330    ...                           17.0          125.0
# 23331    ...                           42.0           40.0
# 23353    ...                          821.0           30.0
# 23354    ...                          141.0           43.0
# 23370    ...                           25.0          211.0
# 23371    ...                          386.0           27.0
# 23374    ...                           52.0          107.0
# 23375    ...                          266.0           52.0
# 23387    ...                           81.0           54.0
# 23393    ...                          147.0           92.0
# 23404    ...                           83.0           96.0
# 23411    ...                          428.0           97.0
#
#        Horizontal Distance  Horizontal Error  Root Mean Square          ID  \
# 2576                   NaN               NaN               NaN  USP0000008
# 2577                   NaN               NaN               NaN  USP000000M
# 2578                   NaN               NaN               NaN  USP000000Q
# 2579                   NaN               NaN               NaN  USP000001H
# 2580                   NaN               NaN               NaN  USP0000022
# 2584                   NaN               NaN               NaN  USP0000042
# 2585                   NaN               NaN               NaN  USP0000058
# 2586                   NaN               NaN               NaN  USP000005S
# 2587                   NaN               NaN               NaN  USP0000067
# 2590                   NaN               NaN               NaN  USP000008B
# 2592                   NaN               NaN               NaN  USP000008W
# 2593                   NaN               NaN               NaN  USP00000A3
# 2594                   NaN               NaN               NaN  USP00000AA
# 2595                   NaN               NaN               NaN  USP00000AP
# 2597                   NaN               NaN               NaN  USP00000BP
# 2598                   NaN               NaN               NaN  USP00000BW
# 2599                   NaN               NaN               NaN  USP00000C9
# 2600                   NaN               NaN               NaN  USP00000DW
# 2602                   NaN               NaN               NaN  USP00000EG
# 2603                   NaN               NaN               NaN  USP00000EP
# 2606                   NaN               NaN               NaN  USP00000G3
# 2607                   NaN               NaN               NaN  USP00000GX
# 23234     US              US               US  Reviewed
# 23235     US              US               US  Reviewed
# 23236     US              US               US  Reviewed
# 23239     US              US               US  Reviewed
# 23241     US              US               US  Reviewed
# 23246     US              US               US  Reviewed
# 23261     US              US               US  Reviewed
# 23327     US              US               US  Reviewed
# 23328     US              US               US  Reviewed
# 23330     US              US               US  Reviewed
# 23331     US              US               US  Reviewed
# 23353     US              US               US  Reviewed
# 23354     US              US               US  Reviewed
# 23370     US              US               US  Reviewed
# 23371     US              US               US  Reviewed
# 23374     US              US               US  Reviewed
# 23375     US              US               US  Reviewed
# 23387     US              US               US  Reviewed
# 23393     US              US               US  Reviewed
# 23404     US              US               US  Reviewed
# 23411     US              US               US  Reviewed
#
# [3761 rows x 21 columns]

# %%
tipo=mb[mb.Type=='Nuclear Explosion']
tipo['Type']
# Out:
# 2797     Nuclear Explosion
# 2859     Nuclear Explosion
# 2876     Nuclear Explosion
# 2897     Nuclear Explosion
# 2951     Nuclear Explosion
# 3126     Nuclear Explosion
# 3205     Nuclear Explosion
# 3218     Nuclear Explosion
# 3269     Nuclear Explosion
# 3286     Nuclear Explosion
# 3331     Nuclear Explosion
# 3374     Nuclear Explosion
# 3445     Nuclear Explosion
# 3488     Nuclear Explosion
# 3661     Nuclear Explosion
# 3663     Nuclear Explosion
# 3674     Nuclear Explosion
# 3739     Nuclear Explosion
# 4004     Nuclear Explosion
# 4035     Nuclear Explosion
# 4071     Nuclear Explosion
# 4109     Nuclear Explosion
# 4161     Nuclear Explosion
# 4180     Nuclear Explosion
# 4275     Nuclear Explosion
# 4347     Nuclear Explosion
# 4454     Nuclear Explosion
# 4465     Nuclear Explosion
# 4543     Nuclear Explosion
# 4544     Nuclear Explosion
#                ...
# 8808     Nuclear Explosion
# 8877     Nuclear Explosion
# 8952     Nuclear Explosion
# 8989     Nuclear Explosion
# 9002     Nuclear Explosion
# 9004     Nuclear Explosion
# 9025     Nuclear Explosion
# 9166     Nuclear Explosion
# 9267     Nuclear Explosion
# 9269     Nuclear Explosion
# 9291     Nuclear Explosion
# 9327     Nuclear Explosion
# 9357     Nuclear Explosion
# 9466     Nuclear Explosion
# 9513     Nuclear Explosion
# 9546     Nuclear Explosion
# 9671     Nuclear Explosion
# 9729     Nuclear Explosion
# 10050    Nuclear Explosion
# 10126    Nuclear Explosion
# 10209    Nuclear Explosion
# 10234    Nuclear Explosion
# 10488    Nuclear Explosion
# 10907    Nuclear Explosion
# 11641    Nuclear Explosion
# 11963    Nuclear Explosion
# 12142    Nuclear Explosion
# 12450    Nuclear Explosion
# 12613    Nuclear Explosion
# 13054    Nuclear Explosion
# Name: Type, dtype: object

# %%
#da um count para ver os valores comuns em relação ao hemisferio att (ta dando um erro que não sei resolver.)
#x=(tipo['Hemisferio'].value_counts(normalize=True)*100).round(decimals=3)
tabela=pd.crosstab(df['Hemisferio'],tipo['Type'], margins=True, rownames=['Hemisferio'],colnames=['Tipos Filtrados apenas para MB'], normalize=True)*100
tabela
# Out:
# Tipos Filtrados apenas para MB  Nuclear Explosion         All
# Hemisferio
# Norte                                   82.822086   82.822086
# Sul                                     17.177914   17.177914
# All                                    100.000000  100.000000

# %% [markdown]
# É mais provável ocorre no hemisfério norte.
