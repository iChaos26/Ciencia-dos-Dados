# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## COLOQUE AQUI SEU NOME
# ___João Gabriel Rodrigues Edivirges

# %% [markdown]
# ## TÍTULO DO SEU PROJETO
# __ Insegurança Alimentar em Famílias com renda abaixo de Um Salário Minimo 2013

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

print(os.getcwd())

dados=pd.read_csv('DOM2013.csv')
# dados.head()
# df.v2103=dados.v2103
# df.v2105=dados.v2105
# df.v2109=dados.v2109
# df.v4621=dados.v4621
# df.v4620=dados.v4620

dados.dtypes

dado=pd.DataFrame({
'Os moradores comeram apenas alguns alimentos que ainda tinha porque o dinheiro acabou':dados.V2109,
'Os alimentos acabaram antes que os moradores tivessem dinheiro':dados.V2105,
'Os moradores tiveram a preocupação de que os alimentos acabassem antes de poderem comprar ou receber mais comida':dados.V2103,
'Rendimento mensal domiciliar per capita':dados.V4621,
'Número de componentes do domícilio':dados.V4620,
'Rendimento mensal domiciliar para todas as unidades domiciliares':dados.V4614
})
dado['Os moradores comeram apenas alguns alimentos que ainda tinha porque o dinheiro acabou']=dado['Os moradores comeram apenas alguns alimentos que ainda tinha porque o dinheiro acabou'].astype('category')
dado['Os moradores comeram apenas alguns alimentos que ainda tinha porque o dinheiro acabou'].cat.categories=["Sim","Não"]
dado['Os alimentos acabaram antes que os moradores tivessem dinheiro']=dado['Os alimentos acabaram antes que os moradores tivessem dinheiro'].astype('category')
dado['Os alimentos acabaram antes que os moradores tivessem dinheiro'].cat.categories=["Sim","Não"]
dado['Os moradores tiveram a preocupação de que os alimentos acabassem antes de poderem comprar ou receber mais comida']=dado['Os moradores tiveram a preocupação de que os alimentos acabassem antes de poderem comprar ou receber mais comida'].astype('category')
dado['Os moradores tiveram a preocupação de que os alimentos acabassem antes de poderem comprar ou receber mais comida'].cat.categories=["Sim","Não"]



dado.dropna(how='all')

dado[(dado['Número de componentes do domícilio']>5) & (dado['Rendimento mensal domiciliar para todas as unidades domiciliares']<969) & (dado['Rendimento mensal domiciliar para todas as unidades domiciliares']>0) ]

#dado.dropna(["coluna1"],['coluna2']) coluna por coluna
# Out:
# C:\Users\joony\Downloads
#         Número de componentes do domícilio  \
# 48                                     7.0
# 56                                     7.0
# 57                                     7.0
# 71                                     6.0
# 145                                    6.0
# 205                                    6.0
# 406                                    7.0
# 542                                    6.0
# 630                                    6.0
# 711                                    7.0
# 1038                                   8.0
# 1264                                   6.0
# 1522                                   7.0
# 1630                                   6.0
# 1849                                   6.0
# 2041                                   6.0
# 2208                                   6.0
# 2250                                   8.0
# 2691                                   7.0
# 2710                                   8.0
# ...

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\joony\Downloads

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
dados.head()
# Out:
#    Unnamed: 0  V0101  UF  V0102  V0103  V0104  V0105  V0106  V0201  V0202  \
# 0           0   2013  11     15      1     11    NaN    NaN    NaN    NaN
# 1           1   2013  11     15      2     10    NaN    NaN    NaN    NaN
# 2           2   2013  11     15      3      1    1.0    1.0    1.0    4.0
# 3           3   2013  11     15      4      1    2.0    2.0    1.0    2.0
# 4           4   2013  11     15      5      1    3.0    3.0    1.0    2.0
#
#      ...     V2123  V2124  V2126  V2128  V2130 V2132 V2134  V2138  V2139  \
# 0    ...       NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 1    ...       NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2    ...       NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 3    ...       NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 4    ...       NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
#
#       V9992
# 0  20150428
# 1  20150428
# 2  20150428
# 3  20150428
# 4  20150428
# ...

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!

# %%
# Out:
# 0         NaN
# 1         NaN
# 2         3.0
# 3         3.0
# 4         3.0
# 5         3.0
# 6         3.0
# 7         3.0
# 8         3.0
# 9         3.0
# 10        1.0
# 11        3.0
# 12        3.0
# 13        NaN
# 14        3.0
# 15        3.0
# 16        3.0
# 17        3.0
# 18        3.0
# 19        3.0
# 20        3.0
# 21        3.0
# 22        3.0
# 23        NaN
# 24        3.0
# 25        3.0
# 26        3.0
# 27        NaN
# 28        3.0
# 29        3.0
#          ...
# 148667    3.0
# 148668    3.0
# 148669    3.0
# 148670    3.0
# 148671    3.0
# 148672    3.0
# 148673    3.0
# 148674    NaN
# 148675    NaN
# 148676    NaN
# 148677    3.0
# 148678    3.0
# 148679    3.0
# 148680    3.0
# 148681    1.0
# 148682    3.0
# 148683    3.0
# 148684    1.0
# 148685    NaN
# 148686    NaN
# 148687    3.0
# 148688    3.0
# 148689    3.0
# 148690    1.0
# 148691    NaN
# 148692    1.0
# 148693    3.0
# 148694    3.0
# 148695    1.0
# 148696    NaN
# ...

# %%
df1=pd.DataFrame()
